# %%
# import necessary libraries
from pathlib import Path
import requests
import pandas as pd

def download_one_file(year: int, month: int) -> Path:
    """
    Downloads the yellow taxi trip data for a given year and month from the TLC website and saves it as a parquet file.

    Args:
    - year (int): The year of the data to download.
    - month (int): The month of the data to download.

    Returns:
    - path (Path): The path to the downloaded parquet file.
    """

    URL = f'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_{year}-{month:02d}.parquet'
    response = requests.get(URL)

    if response.status_code == 200:
        path = f'../data/raw/rides_{year}-{month:02d}.parquet'
        open(path, 'wb').write(response.content)
        return path
    else:
        raise Exception(f'{URL} is not available.')

# %%
# explore and validate one single file
download_one_file(year=2023, month=1)

rides = pd.read_parquet('../data/raw/rides_2023-01.parquet')
rides.head(20)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[13], line 4
#       1 # explore and validate one single file
#       2 download_one_file(year=2023, month=1)
# ----> 4 rides = pd.read_parquet('../data/raw/rides_2023-01.parquet')
#       5 rides.head(20)
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pandas/core/arrays/arrow/extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File /opt/anaconda3/envs/nyc-taxi-ml/lib/python3.14/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined
